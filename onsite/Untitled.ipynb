# %% [markdown]
# ## Dot counter

# %%
import cv2

# %%
import numpy

# %%
import matplotlib.pyplot as plt

# %%
# !ls -l
# Out:
# total 2592
# -rw-rw-r-- 1 jovyan  1000  173259 Oct 24 16:45 'autodraw 10_24_2022.png'
# -rw-rw-r-- 1 jovyan  1000    3143 Oct 24 17:26  cutted.png
# -rw-rw-r-- 1 jovyan  1000 2371896 Oct 24 17:18  IMG_7695.JPG
# drwxrwxr-x 2 jovyan  1000    4096 Aug 29 14:54  lesson00
# drwxrwxr-x 2 jovyan  1000    4096 Aug 29 14:54  lesson02
# drwxrwxr-x 2 jovyan  1000    4096 Aug 29 14:54  lesson03
# drwxrwxr-x 2 jovyan  1000    4096 Oct  4 16:20  lesson04
# drwxrwxr-x 2 jovyan  1000    4096 Aug 29 14:54  lesson05
# drwxrwxr-x 4 jovyan  1000    4096 Aug 29 14:54  lesson06
# drwxrwxr-x 2 jovyan  1000    4096 Aug 29 14:54  lesson08
# drwxrwxr-x 2 jovyan  1000    4096 Sep  5 16:21  lesson09
# -rw-r--r-- 1 jovyan users   63212 Oct 24 17:26  Untitled.ipynb

# %%
image = cv2.imread("cutted5.png")

# %%
plt.imshow(image)

# %%
grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(grayscale, cmap="gray")

# %%
blur = cv2.GaussianBlur(grayscale, (11, 11), 0)

# %%
plt.imshow(blur)

# %%
canny = cv2.Canny(blur, 100, 200, 3)

# %%
plt.imshow(canny)

# %%
dilated = cv2.dilate(canny, (1, 1), iterations=0)

# %%
plt.imshow(grayscale, cmap="gray")

# %%
plt.imshow(canny, cmap="gray")

# %%
print(len(cnt))
# Out:
# 18

# %%
(cnt, hierarchy) = cv2.findContours(
    dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# cv2.drawContours(rgb, cnt, -1, (0, 255, 0), 2)

# %%
plt.subplot(1, 3, 1)
plt.imshow(grayscale, cmap="gray")

plt.subplot(1, 3, 2)
plt.imshow(blur)

plt.subplot(1, 3, 3)
plt.imshow(canny, cmap="gray")

# %%
print(len(cnt))
# Out:
# 18
